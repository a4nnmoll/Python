# %% [markdown]
# #EXPERIMENT:1

# %% [markdown]
# 1-Print Strings in Given Format

# %%
print("Hello Everyone !!!")

print("Hello")
print("World")

print("Hello")
print("        World")

print("' ANMOL's date of birth is 01\\01\\2005'")
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
#         World
# ' ANMOL's date of birth is 01\01\2005'

# %% [markdown]
# 2-Declare and Print String Variable

# %%
x = "Hello"
print(x)
# Out:
# Hello

# %% [markdown]
# 3-Print Different Data Types

# %%
a = 10
b = 3.14
c = "Python"
d = True

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 3.14
# Python
# True

# %% [markdown]
# 4-First Name + Last Name

# %%
a = input("Enter first name: ")
b = input("Enter last name: ")
print(a + " " + b)
# Out:
# ANMOL CHHETRI

# %% [markdown]
# 5-Print Name with Nickname

# %%
first = input("First name: ")
nick = input("Nickname: ")
last = input("Last name: ")

print(first + " (" + nick + ") " + last)
# Out:
# ANMOL (A4) CHHETRI

# %% [markdown]
# 7-Student Details Format

# %%
print("NAME: ANMOL CHHETRI")
print("SAP ID: 590020076")
print("DATE OF BIRTH: 01 01 2005")
print("ADDRESS: UPES")
print("        Bidholi Campus")
print("        Pincode: 248007")
print("Programme: CYBERSECURITY")
print("Semester: 2")
# Out:
# NAME: ANMOL CHHETRI
# SAP ID: 590020076
# DATE OF BIRTH: 01 01 2005
# ADDRESS: UPES
#         Bidholi Campus
#         Pincode: 248007
# Programme: CYBERSECURITY
# Semester: 2
